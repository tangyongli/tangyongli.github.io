# %% [markdown]
# # Figure
#
# ![alt text](image/image.png)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(2, 2), facecolor='lightskyblue',
                 layout='constrained') # only create one Figure class,it is empty, only when add axis,it will show figure
fig.suptitle('Figure')
ax = fig.add_subplot()
ax.set_title('Axes', loc='left', fontstyle='oblique', fontsize='medium')

# %% [markdown]
# # Axis
# Matplotlib uses Axes to refer to the drawing area that contains data, x- and y-axis, ticks, labels, title<br>
# in the picture, the axis is creare with 'ax = fig.subplots()'. Everything else on the figure was created with methods on this ax object, or can be accessed from it.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The way to create one axis
# An Axes object 封装 all the elements of an individual (sub-)plot in a figure. It contains most of the (sub-)plot elements: Axis, Tick, Line2D, Text, Polygon, etc., and sets the coordinate system.
# `fig, (ax1, ax2, ax3) = plt.subplots(figsize=(13, 3), ncols=3)`
# `ax = fig.subplots()`<br>
# `fig.add_axes([0, 0, 1, 1])`<br>
# `pyplot.subplot_mosaic` and `Figure.subplot_mosaic`: add a grid of named Axes and return a dictionary of axes.<br>
# `fig, axs = plt.subplot_mosaic([['left', 'right'], ['bottom', 'bottom']]), axs['left']`

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Axes plotting methods

# %%
## plot
fig, ax = plt.subplots(figsize=(4, 3))
np.random.seed(19680801)
t = np.arange(100)
x = np.cumsum(np.random.randn(100))
lines = ax.plot(t, x)
## labelling and annotation
linesx = ax.plot(t, x, label='Random walk x')
linesy = ax.plot(t, y, label='Random walk y')
ax.set_xlabel('Time [s]')
ax.set_ylabel('Distance [km]')
ax.legend()
## scales, and ticking
ax.set_yscale('log')
ax.set_xlim([20, 180]) # x轴的范围
# set_yticks，set_xticks
# the tick location,tick color and label position、color can be adjusted with tick_params method.
ax.tick_params(top=True, labeltop=True, color='red', axis='x',
               labelcolor='green')

# %%
# axis layout
fig, axs = plt.subplots(ncols=4, figsize=(7, 2.5), layout='constrained')
np.random.seed(19680801)
t = np.arange(200)
x = np.cumsum(np.random.randn(200))
axs[0].plot(t, x)
axs[0].set_title('aspect="auto"')

axs[1].plot(t, x)
axs[1].set_aspect(3) # show different width of subplots
axs[1].set_title('aspect=3')
axs[2].plot(t, x)
axs[2].set_title('aspect="auto"')
axs[3].plot(t, x)
axs[3].set_title('aspect="auto"')

# %%
import matplotlib.pyplot as plt
import matplotlib.artist as martist
import numpy as np
fig, ax = plt.subplots()
x, y = np.random.rand(2, 100)
lines = ax.plot(x, y, '-', label='example')
lines[0].set(color='green', linewidth=2) # change the properity of line object.
martist.getp(lines[0]) # 输出all the properities of lines object 
ax.legend()
print(lines)
print(ax.get_lines()[0])
lines[0].remove() # remove one object

# %% [markdown]
# ## Text

# %% [markdown]
# `Axes.text(x, y, string, fontdict=None, **kwargs)`<br>
# x,y is the corrds,you can specify text in axis coords ((0, 0) is lower-left and (1, 1) is upper-right<br>
# string is the content  you want to add

# %% [markdown]
# # Color

# %% [markdown]
# ## 色系

# %%
# Sort colors by hue, saturation, value and name.
import matplotlib.colors as mcolors
base=mcolors.BASE_COLORS
css4=mcolors.CSS4_COLORS
    
names = sorted(css4, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
list(base)
names
# Out:
# ['black',
#  'dimgray',
#  'dimgrey',
#  'gray',
#  'grey',
#  'darkgray',
#  'darkgrey',
#  'silver',
#  'lightgray',
#  'lightgrey',
#  'gainsboro',
#  'whitesmoke',
#  'white',
#  'snow',
#  'rosybrown',
#  'lightcoral',
#  'indianred',
#  'brown',
#  'firebrick',
#  'maroon',
#  'darkred',
#  'red',
#  'mistyrose',
#  'salmon',
#  'tomato',
#  'darksalmon',
#  'coral',
#  'orangered',
#  'lightsalmon',
#  'sienna',
#  'seashell',
#  'chocolate',
#  'saddlebrown',
#  'sandybrown',
#  'peachpuff',
#  'peru',
#  'linen',
#  'bisque',
#  'darkorange',
#  'burlywood',
#  'antiquewhite',
#  'tan',
#  'navajowhite',
#  'blanchedalmond',
#  'papayawhip',
#  'moccasin',
#  'orange',
#  'wheat',
#  'oldlace',
#  'floralwhite',
#  'darkgoldenrod',
#  'goldenrod',
#  'cornsilk',
#  'gold',
#  'lemonchiffon',
#  'khaki',
#  'palegoldenrod',
#  'darkkhaki',
#  'ivory',
#  'beige',
#  'lightyellow',
#  'lightgoldenrodyellow',
#  'olive',
#  'yellow',
#  'olivedrab',
#  'yellowgreen',
# ...

# %%
import math

import matplotlib.pyplot as plt

import matplotlib.colors as mcolors
from matplotlib.patches import Rectangle


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * ncols + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * ncols)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
plot_colortable(css4, ncols=4, sort_colors=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## colorbar
# colorbar(self, mappable, cax=None, ax=None, use_gridspec=True, **kw)
# `fig.colorbar(img, ax=ax1, orientation='horizontal',pad=0.1,shrink=0.5,extend="both",label="Count")`,pad is the distance of colorbar with fig. shrink control the length of colorbar.

# %%
import matplotlib.pyplot as plt
import numpy as np

# setup some generic data
N = 37
x, y = np.mgrid[:N, :N]
Z = (np.cos(x*0.2) + np.sin(y*0.3))

# mask out the negative and positive values, respectively
Zpos = np.ma.masked_less(Z, 0)
Zneg = np.ma.masked_greater(Z, 0)

fig, (ax1, ax2, ax3) = plt.subplots(figsize=(13, 3), ncols=3)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax1.imshow(Zpos, cmap='Blues', interpolation='none')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax1)

# repeat everything above for the negative data
# you can specify location, anchor and shrink the colorbar
neg = ax2.imshow(Zneg, cmap='Reds_r', interpolation='none')
cbar2=fig.colorbar(neg, ax=ax2, location='right', anchor=(0, 0.3), shrink=0.7)
cbar2.minorticks_on()

# Plot both positive and negative values between +/- 1.2
pos_neg_clipped = ax3.imshow(Z, cmap='RdBu', vmin=-1.2, vmax=1.2,
                             interpolation='none')
# Add minorticks on the colorbar to make it easy to read the
# values off the colorbar.
# extend='both' makes the end of colorbar with arrow shape
cbar = fig.colorbar(pos_neg_clipped, ax=ax3,extend='both')
cbar.minorticks_on()
plt.show()

# %% [markdown]
# # Examples

# %%
vector_data=gdf.read_file(r"D:\Geodata\xian\district\district.shp",encoding='utf-8').to_crs(epsg=4326)
clip_bound = box(106.2, 30.2, 107.2, 31)
# 裁剪GeoDataFrame
vector_data = vector_data.clip(clip_bound)
vector_data.plot(ax=ax, edgecolor='red', linewidth=1, alpha=0.5)
raster_data=rio.open(path)
array=raster_data.read(1)
raster_extent = rasterio.plot.plotting_extent(raster_data)
# 使用获取的边界作为 extent 参数
img = ax1.imshow(array, cmap=cmap, extent=raster_extent)
# or show(raster_data, ax=ax1,origin='upper', transform=ccrs.PlateCarree(), interpolation='nearest', cmap=cmap)
cbar = fig.colorbar(img, ax=ax1, orientation='horizontal',pad=0.1,shrink=0.5,extend="both",label="Count")
#cbar.set_ticks(np.linspace(array.min(), array.max(), num=5))  # 设置5个刻度
# 设置 colorbar 的刻度位置
cbar.set_ticks([0, 5, 10, 15, 20, 40])
plt.show()
